# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
ds=pd.read_csv(r"C:\Users\bhava\Downloads\petrol\sample.csv")

# %%
ds.head()
# Out:
#          Date     A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# 0  01/02/1995  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1  01/09/1995  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 2  01/16/1995  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 3  01/23/1995  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 4  01/30/1995  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
#
#       P1     P2     P3     D1
# 0  1.272  1.250  1.386  1.104
# 1  1.279  1.256  1.387  1.102
# 2  1.271  1.249  1.385  1.100
# 3  1.277  1.256  1.378  1.095
# 4  1.275  1.255  1.370  1.090

# %%
ds.tail()
# Out:
#             Date     A1     A2     A3     R1     R2     R3     M1     M2  \
# 1356  12/28/2020  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482
# 1357  01/04/2021  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484
# 1358  01/11/2021  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550
# 1359  01/18/2021  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601
# 1360  01/25/2021  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615
#
#          M3     P1     P2     P3     D1
# 1356  2.858  2.889  2.770  3.031  2.635
# 1357  2.867  2.895  2.771  3.042  2.640
# 1358  2.927  2.959  2.839  3.101  2.670
# 1359  2.995  3.014  2.885  3.166  2.696
# 1360  3.014  3.033  2.900  3.191  2.716

# %%
ds.shape
# Out:
# (1361, 14)

# %%
ds.describe()
# Out:
#                 A1           A2           A3           R1           R2  \
# count  1361.000000  1361.000000  1361.000000  1361.000000  1361.000000
# mean      2.285680     2.234511     2.396873     2.225170     2.178511
# std       0.859028     0.843815     0.883311     0.850143     0.835549
# min       0.949000     0.926000     1.039000     0.907000     0.885000
# 25%       1.461000     1.433000     1.550000     1.421000     1.393000
# 50%       2.326000     2.251000     2.458000     2.237000     2.175000
# 75%       2.903000     2.825000     3.060000     2.828000     2.765000
# max       4.165000     4.102000     4.301000     4.114000     4.054000
#
#                 R3           M1           M2           M3           P1  \
# count  1361.000000  1361.000000  1361.000000  1361.000000  1361.000000
# mean      2.329126     2.382822     2.320970     2.508877     2.519840
# std       0.876739     0.882107     0.858521     0.908861     0.911055
# ...

# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c3d483a1c074> in <module>
# ----> 1 data.columns
#
# NameError: name 'data' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
ds.columns
# Out:
# Index(['Date', 'A1', 'A2', 'A3', 'R1', 'R2', 'R3', 'M1', 'M2', 'M3', 'P1',
#        'P2', 'P3', 'D1'],
#       dtype='object')

# %%
ds.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f37aa051ea64> in <module>
# ----> 1 ds.rows
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
ds.nunique()
# Out:
# Date    1361
# A1      1037
# A2      1025
# A3      1050
# R1      1046
# R2      1031
# R3      1060
# M1      1051
# M2      1045
# M3      1059
# P1      1045
# P2      1043
# P3      1055
# D1      1034
# dtype: int64

# %%
ds['A1'].unique()
# Out:
# array([1.127, 1.134, 1.126, ..., 2.33 , 2.464, 2.478])

# %%
ds.isnull().sum()
# Out:
# Date    0
# A1      0
# A2      0
# A3      0
# R1      0
# R2      0
# R3      0
# M1      0
# M2      0
# M3      0
# P1      0
# P2      0
# P3      0
# D1      0
# dtype: int64

# %%
demo=ds.drop(['A1'],axis=1)

# %%
ds.columns
# Out:
# Index(['Date', 'A1', 'A2', 'A3', 'R1', 'R2', 'R3', 'M1', 'M2', 'M3', 'P1',
#        'P2', 'P3', 'D1'],
#       dtype='object')

# %%
ds.dtypes
# Out:
# Date     object
# A1      float64
# A2      float64
# A3      float64
# R1      float64
# R2      float64
# R3      float64
# M1      float64
# M2      float64
# M3      float64
# P1      float64
# P2      float64
# P3      float64
# D1      float64
# dtype: object

# %%
ds.drop("A1",axis=1)
# Out:
#             Date     A2     A3     R1     R2     R3     M1     M2     M3  \
# 0     01/02/1995  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1     01/09/1995  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 2     01/16/1995  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 3     01/23/1995  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 4     01/30/1995  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1356  12/28/2020  2.225  2.535  2.243  2.158  2.423  2.634  2.482  2.858
# 1357  01/04/2021  2.227  2.549  2.249  2.160  2.437  2.639  2.484  2.867
# 1358  01/11/2021  2.298  2.610  2.317  2.232  2.498  2.702  2.550  2.927
# 1359  01/18/2021  2.351  2.688  2.379  2.285  2.579  2.759  2.601  2.995
# 1360  01/25/2021  2.363  2.703  2.392  2.298  2.593  2.776  2.615  3.014
#
#          P1     P2     P3     D1
# 0     1.272  1.250  1.386  1.104
# ...

# %%
ds.rename(columns={"A2":"rate"})
# Out:
#             Date     A1   rate     A3     R1     R2     R3     M1     M2  \
# 0     01/02/1995  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159
# 1     01/09/1995  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164
# 2     01/16/1995  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155
# 3     01/23/1995  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165
# 4     01/30/1995  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1356  12/28/2020  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482
# 1357  01/04/2021  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484
# 1358  01/11/2021  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550
# 1359  01/18/2021  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601
# 1360  01/25/2021  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615
#
#          M3     P1     P2     P3     D1
# 0     1.298  1.272  1.250  1.386  1.104
# ...

# %%
corelation=demo.corr()

# %%
sb.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sb.pairplot(demo)

# %%
sb.distplot(demo["R1"])
# Out:
# C:\Users\bhava\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='R1', ylabel='Density'>
